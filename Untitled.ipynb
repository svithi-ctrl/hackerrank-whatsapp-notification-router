# %%
import pandas as pd

messages = pd.read_csv("messages.csv")
users = pd.read_csv("users.csv")
groups = pd.read_csv("groups.csv")
history = pd.read_csv("message_history.csv")
events = pd.read_csv("message_events.csv")
user_business_history = pd.read_csv("user_business_history.csv")
business_acc = pd.read_csv("business_accounts.csv")
members = pd.read_csv("group_members.csv")
voice_notes = pd.read_csv("voice_notes.csv")
image = pd.read_csv("images.csv")
notif = pd.read_csv("daily_notification_summary.csv")

print(messages.head())
print(messages.columns)

print(users.head())
print(users.columns)
# Out:
#   message_id user_id conversation_type   group_id   business_id  \
# 0    msg_023   u_002          business        NaN  business_002
# 1    msg_091   u_028          personal        NaN           NaN
# 2    msg_090   u_034          personal        NaN           NaN
# 3    msg_048   u_011             group  group_011           NaN
# 4    msg_040   u_007             group  group_001           NaN
#
#   sender_user_id        created_at  \
# 0            NaN  2026-07-30 22:19
# 1          u_049  2026-07-24 18:07
# 2          u_050  2026-07-20 15:02
# 3          u_053  2026-07-20 08:51
# 4          u_051  2026-07-31 08:02
#
#                                         message_text media_type media_id  \
# 0  Important Information\n\nDear Customer,\n\nYou...        NaN      NaN
# 1  Your workspace access will expire today. Reply...        NaN      NaN
# 2  Hi, is this Arun from Bluebell Apartments? I g...        NaN      NaN
# ...

# %%
print(image.head())
print(image.columns)
# Out:
#   image_id                 file_path
# 0  img_001  media/images/img_001.jpg
# 1  img_002  media/images/img_002.jpg
# 2  img_003  media/images/img_003.jpg
# 3  img_004  media/images/img_004.jpg
# 4  img_005  media/images/img_005.jpg
# Index(['image_id', 'file_path'], dtype='str')

# %%
import pandas as pd

pd.set_option("display.max_colwidth", None)

history = pd.read_csv("dataset/message_history.csv")

for i, row in history.head(15).iterrows():
    print("=" * 100)
    print(row)
# Out:
# ...
# message_id                                                                                                  message_0107
# user_id                                                                                                            u_008
# conversation_type                                                                                               business
# group_id                                                                                                             NaN
# business_id                                                                                                 business_036
# sender_user_id                                                                                                       NaN
# created_at                                                                                              2026-05-23 17:46
# message_text         Delivery failed. Pay small reattempt fee at amazonpay-delivery.in and enter OTP to release package.
# ...

# %%
import pandas as pd

df = pd.read_csv("output.csv")

print(df["action"].value_counts())
print(df["message_type"].value_counts())
# Out:
# action
# digest    57
# notify    27
# mute      26
# Name: count, dtype: int64
# message_type
# unknown            31
# event              22
# forward            17
# payment            13
# scam                9
# personal            6
# urgent              6
# business_update     3
# promotion           3
# Name: count, dtype: int64
